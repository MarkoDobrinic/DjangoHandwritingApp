# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#chars = np.save('styles/style-13-chars.npy', np.array(b'please tell me more'))

# %%
style = 13
strokes = np.load('styles/style-{}-strokes.npy'.format(style))
chars = np.load('styles/style-{}-chars.npy'.format(style))

# %%
chars
# Out:
# array(b&#39;dfafdas dafaf a&#39;, dtype=&#39;|S15&#39;)

# %%
cum = np.cumsum(strokes[:, 0:2], axis=0)
cum = (cum - np.mean(cum, axis=0)) / np.std(cum, axis=0)
plt.figure(figsize=(20, 4))
plt.scatter(cum[:, 0], -cum[:, 1])

strokes = (strokes - np.mean(strokes, axis=0)) / np.std(strokes, axis=0)
# Out:
# &lt;matplotlib.figure.Figure at 0x7f44d07f3be0&gt;

# %%
plt.figure(figsize=(20, 4))
plt.scatter(strokes[:, 0], strokes[:, 1])
# Out:
# &lt;matplotlib.collections.PathCollection at 0x7f450426c128&gt;
# &lt;matplotlib.figure.Figure at 0x7f44d0723828&gt;
